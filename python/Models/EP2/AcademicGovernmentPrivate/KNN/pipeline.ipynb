# %% [markdown]
# # Pipelines de treinamento: KNN
#
# Esse notebook contém as pipelines de treinamento usadas na obtenção do melhor modelo classificador do problema desenvolvido no EP2.
#
# O modelo KNN aceita diversas parametrizações diferentes - veja documentação: https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html#sklearn.neighbors.KNeighborsClassifier - aqui exploramos três: *neighbors* e *weights*.
#
# As **features** que exploramos aqui são:
#
# 1. Bag of Words
# 2. TF/TF-IDF
# 3. CHAR NGrams
# 4. Embeddings
#
# Os **modelos de embeddings** que exploramos aqui são:
#
# 1. BAAI bge-3
# 2. Google Gemma 300m
#
# PS: Os embeddings Gemma 300m eu ainda NÃO CONSEGUI GERAR. Então, não precisa testar a parte que roda com eles no EP.
#
# Você pode encontrar uma execução já parametrizada do melhor modelo encontrado por essas pipelines no notebook model.ipynb, **que é nossa versão de entrega do EP2**.

# %% [markdown]
# ## Bootstrap Imports

# %%
import pandas as pd
import numpy as np

import os
import sys
from pathlib import Path

# %% [markdown]
# ### Teste de importação: Lib.utils do projeto

# %%
filedir = Path(os.getcwd())
base_path = filedir.resolve().parents[3]
sys.path.append(str(base_path))

from Lib.utils import printhello
printhello()
# Out:
# HELLO!

# %% [markdown]
# ## Configura variáveis de execução

# %%
sep = ";"
dec = ","
quotech = "\""
encoding = "latin-1"


EP_dir = "EP2"
CSV_input_name = "ep2-train.csv"
path_to_archive = f"../../../../Traindata/{EP_dir}/{CSV_input_name}"


do_print = True
if do_print:
    print(f"Path to csv input is:  {path_to_archive}")
# Out:
# Path to csv input is:  ../../../../Traindata/EP2/ep2-train.csv

# %% [markdown]
# ### Configure variáveis de reprodutibilidade

# %%
random_state = 12345

# %% [markdown]
# ### Lista de melhores modelos

# %%
best_models_list = []

# %% [markdown]
# ## Pré-tratamento de dados

# %% [markdown]
# ### Importar dados do csv

# %%
df = pd.read_csv(path_to_archive, na_values=['na'],
sep=sep,
decimal=dec,
quotechar=quotech,
encoding=encoding,
encoding_errors='strict')
print(df.shape)
print(df.columns)
# Out:
# (43678, 2)
# Index(['req_text', 'profession'], dtype='object')

# %% [markdown]
# ### Embaralhamento dos dados
#
# O .csv de entrada tem alto ordenamento dos inputs por classe. Carregá-los dessa maneira nos modelos p/ treinamento introduz viés, então é preciso embaralhar os dados para garantir randomicidade.
# As classes em sklearn.model_selection - como a StratfiedKFold usada mais a frente - implementam parâmetro shuffle="", que pode ser passado como True para embaralhar mais os dados.
#
# Note que é importante também garantir a reprodutibilidade do embaralhamento, especificando um valor hardcoded (Neste caso random_state=100)

# %%
print("Shape antes do shuffle:", df.shape)

df = df.sample(frac=1, random_state=random_state).reset_index(drop=True) #NAO MUDE random_state, essa variavel DEVE valer 12345, ou QUEBRARÁ REPRODUTIBILIDADE dos experimentos

print("Shape depois do shuffle:", df.shape)
# Out:
# Shape antes do shuffle: (43678, 2)
# Shape depois do shuffle: (43678, 2)

# %% [markdown]
# ### Limpeza dos dados

# %%
from Lib.utils import clean_text
#def clean_text(text, do_lowercase: bool, rem_emails: bool, rem_urls: bool, normalize_whitespaces: bool):

df['req_text_cleaned'] = df['req_text'].apply(lambda row_text: clean_text(
        row_text, 
        do_lowercase=True, 
        rem_emails=True, 
        rem_urls=True, 
        normalize_whitespaces=True
    ))

df['req_text'] = df['req_text_cleaned']
df = df.drop(columns=['req_text_cleaned']) # Remove a coluna temporária

# %% [markdown]
# # Treino dos modelos KNN

# %% [markdown]
# ## Imports

# %%
import gc

from sklearn.neighbors import KNeighborsClassifier
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.feature_selection import SelectKBest, chi2
from imblearn.under_sampling import RandomUnderSampler
from sklearn.preprocessing import Normalizer
from sklearn.decomposition import PCA
from sklearn.decomposition import IncrementalPCA
import math

# %% [markdown]
# ### Disable Warnings

# %%
import warnings
from sklearn.exceptions import ConvergenceWarning

# Ignora warnings de ConvergenceWarning
warnings.filterwarnings("ignore", category=ConvergenceWarning)

# Ignora UserWarnings específicos de l1_ratio etc
warnings.filterwarnings("ignore", category=UserWarning)

# %% [markdown]
# ## Training Features: Embeddings

# %% [markdown]
# ### Algoritmo & parâmetros

# %%
knn = KNeighborsClassifier()
# Out:
# '\nIncremental PCA\nfrom sklearn.decomposition import IncrementalPCA\n\nipca = IncrementalPCA(n_components=10, batch_size=5000)\nX_baai_pca_10 = ipca.fit_transform(X_baai_norm)\n\nfor i, batch in enumerate(np.array_split(X_baai_norm, n_batches)):\n    ipca.partial_fit(batch)\n    print(f"Lote {i+1}/{n_batches} concluído")\n\n\nRandomized Solver\nfrom sklearn.decomposition import PCA\n\npca = PCA(n_components=10, random_state=random_state, svd_solver=\'randomized\')\nX_baai_pca_10 = pca.fit_transform(X_baai_norm)\n\n'

# %% [markdown]
# # Treino c/ embeddings do modelo: BAAI-bge-3

# %% [markdown]
# ## Importação dos embeddings

# %%
X_baai = np.load('../../Embeddings/npys/embeddings_baai_bge3.npy')
y_baai = df["profession"].values

# %% [markdown]
# ## Undersampling e Normalização

# %%
undersampler = RandomUnderSampler(
    sampling_strategy={
        'government': 10303,
        'academic': 10303,
        'private': 10303,
    },
    random_state=random_state
)
normalizer = Normalizer(norm='l2') 

X_baai_under, y_baai_under = undersampler.fit_resample(X_baai, y_baai) #Gera X e y undersampleados

# %%
X_baai_norm_under = normalizer.fit_transform(X_baai_under) #Nomaliza vetores de treino undersampleados
X_baai_norm = normalizer.fit_transform(X_baai) #Nomaliza vetores de treino originais

# %% [markdown]
# ## Aplicação dos PCAs & Treino dos modelos

# %% [markdown]
# ### Variáveis p/ PCA

# %%
batch_size = 10000
n_batches = math.ceil(len(X_baai_norm)/batch_size)

# %% [markdown]
# ### PCA 10

# %% [markdown]
# #### Full sample

# %%
ipca_10 = IncrementalPCA(n_components=10, batch_size=batch_size)
X_baai_pca_10 = ipca_10.fit_transform(X_baai_norm)

for i, batch in enumerate(np.array_split(X_baai_norm, n_batches)):
    print(f"Fitando batch {i+1}")
    ipca_10.partial_fit(batch)
    print(f"Lote {i+1}/{n_batches} concluído")
# Out:
# Fitando batch 1
# Lote 1/5 concluído
# Fitando batch 2
# Lote 2/5 concluído
# Fitando batch 3
# Lote 3/5 concluído
# Fitando batch 4
# Lote 4/5 concluído
# Fitando batch 5
# Lote 5/5 concluído

# %%
#X_baai_pca_10 = PCA(n_components=10, random_state=random_state).fit_transform(X_baai_norm)

knn_grid_baai_10 = GridSearchCV(knn, # Modelo
                                { # Parâmetros
                                    'n_neighbors': range(2, 11),
                                    'weights': ['uniform', 'distance']
                                }, 
                                cv=10, # Configs 
                                n_jobs=-1, 
                                scoring="accuracy", 
                                verbose=1, 
                                error_score=np.nan) 


knn_grid_baai_10.fit(X_baai_pca_10, y_baai)
# Out:
# Fitting 10 folds for each of 18 candidates, totalling 180 fits
# GridSearchCV(cv=10, estimator=KNeighborsClassifier(), n_jobs=-1,
#              param_grid={'n_neighbors': range(2, 11),
#                          'weights': ['uniform', 'distance']},
#              scoring='accuracy', verbose=1)

# %%
print("Melhor acurácia média:", knn_grid_baai_10.best_score_)
print("Melhores parâmetros:", knn_grid_baai_10.best_params_)

best_models_list.append({
    "features": "embeddings baai-bge-3",
    "PCA": "10",
    "undersampled": False,
    "accuracy": knn_grid_baai_10.best_score_,
    "params": knn_grid_baai_10.best_params_.copy(),
})
#0.6277532501084139
# Out:
# Melhor acurácia média: 0.6277532501084139
# Melhores parâmetros: {'n_neighbors': 10, 'weights': 'distance'}

# %% [markdown]
# #### Undersample

# %%
ipca_10_under = IncrementalPCA(n_components=10, batch_size=batch_size)
X_baai_pca_10_under = ipca_10_under.fit_transform(X_baai_norm)

for i, batch in enumerate(np.array_split(X_baai_norm, n_batches)):
    print(f"Fitando batch {i+1}")
    ipca_10_under.partial_fit(batch)
    print(f"Lote {i+1}/{n_batches} concluído")
# Out:
# Fitando batch 1
# Lote 1/5 concluído
# Fitando batch 2
# Lote 2/5 concluído
# Fitando batch 3
# Lote 3/5 concluído
# Fitando batch 4
# Lote 4/5 concluído
# Fitando batch 5
# Lote 5/5 concluído

# %%
#X_baai_pca_10_under = PCA(n_components=10, random_state=random_state).fit_transform(X_baai_norm_under)

knn_grid_baai_10_under = GridSearchCV(knn, # Modelo
                                { # Parâmetros
                                    'n_neighbors': range(2, 11),
                                    'weights': ['uniform', 'distance']
                                }, 
                                cv=10, # Configs 
                                n_jobs=-1, 
                                scoring="accuracy", 
                                verbose=1, 
                                error_score=np.nan) 
# 3. Fitar (Treinar) usando os embeddings pré-calculados
knn_grid_baai_10_under.fit(X_baai_pca_10_under, y_baai_under)
# Out:
# Fitting 10 folds for each of 18 candidates, totalling 180 fits
# GridSearchCV(cv=10, estimator=KNeighborsClassifier(), n_jobs=-1,
#              param_grid={'n_neighbors': range(2, 11),
#                          'weights': ['uniform', 'distance']},
#              scoring='accuracy', verbose=1)

# %%
print("Melhor acurácia média:", knn_grid_baai_10_under.best_score_)
print("Melhores parâmetros:", knn_grid_baai_10_under.best_params_)

best_models_list.append({
    "features": "embeddings baai-bge-3",
    "PCA": "10",
    "undersampled": True,
    "accuracy": knn_grid_baai_10_under.best_score_,
    "params": knn_grid_baai_10_under.best_params_.copy(),
})
# Out:
# Melhor acurácia média: 0.6277532501084139
# Melhores parâmetros: {'n_neighbors': 10, 'weights': 'distance'}

# %% [markdown]
# #### Liberação de Memória

# %%
del knn_grid_baai_10
del X_baai_pca_10
del ipca_10

del knn_grid_baai_10_under
del X_baai_pca_10_under
del ipca_10_under
gc.collect()
# Out:
# 54

# %% [markdown]
# ## PCA 20

# %% [markdown]
# ### Full sample

# %%
ipca_20 = IncrementalPCA(n_components=20, batch_size=batch_size)
X_baai_pca_20 = ipca_20.fit_transform(X_baai_norm)

for i, batch in enumerate(np.array_split(X_baai_norm, n_batches)):
    print(f"Fitando batch {i+1}")
    ipca_20.partial_fit(batch)
    print(f"Lote {i+1}/{n_batches} concluído")
# Out:
# Fitando batch 1
# Lote 1/5 concluído
# Fitando batch 2
# Lote 2/5 concluído
# Fitando batch 3
# Lote 3/5 concluído
# Fitando batch 4
# Lote 4/5 concluído
# Fitando batch 5
# Lote 5/5 concluído

# %%
#Fazer PCA

knn_grid_baai_20 = GridSearchCV(knn, # Modelo
                                { # Parâmetros
                                    'n_neighbors': range(2, 21),
                                    'weights': ['uniform', 'distance']
                                }, 
                                cv=10, # Configs 
                                n_jobs=-1, 
                                scoring="accuracy", 
                                verbose=1, 
                                error_score=np.nan) 


knn_grid_baai_20.fit(X_baai_pca_20, y_baai)
# Out:
# Fitting 10 folds for each of 38 candidates, totalling 380 fits
# GridSearchCV(cv=10, estimator=KNeighborsClassifier(), n_jobs=-1,
#              param_grid={'n_neighbors': range(2, 21),
#                          'weights': ['uniform', 'distance']},
#              scoring='accuracy', verbose=1)

# %%
print("Melhor acurácia média:", knn_grid_baai_20.best_score_)
print("Melhores parâmetros:", knn_grid_baai_20.best_params_)

best_models_list.append({
    "features": "embeddings baai-bge-3",
    "PCA": "20",
    "undersampled": False,
    "accuracy": knn_grid_baai_20.best_score_,
    "params": knn_grid_baai_20.best_params_.copy(),
})
# Out:
# Melhor acurácia média: 0.6490686685271069
# Melhores parâmetros: {'n_neighbors': 12, 'weights': 'distance'}

# %% [markdown]
# ### Undersample

# %%
ipca_20_under = IncrementalPCA(n_components=20, batch_size=batch_size)
X_baai_pca_20_under = ipca_20_under.fit_transform(X_baai_norm)

for i, batch in enumerate(np.array_split(X_baai_norm, n_batches)):
    print(f"Fitando batch {i+1}")
    ipca_20_under.partial_fit(batch)
    print(f"Lote {i+1}/{n_batches} concluído")
# Out:
# Fitando batch 1
# Lote 1/5 concluído
# Fitando batch 2
# Lote 2/5 concluído
# Fitando batch 3
# Lote 3/5 concluído
# Fitando batch 4
# Lote 4/5 concluído
# Fitando batch 5
# Lote 5/5 concluído

# %%
#Fazer PCA

knn_grid_baai_20_under = GridSearchCV(knn, # Modelo
                                { # Parâmetros
                                    'n_neighbors': range(2, 21),
                                    'weights': ['uniform', 'distance']
                                }, 
                                cv=20, # Configs 
                                n_jobs=-1, 
                                scoring="accuracy", 
                                verbose=1, 
                                error_score=np.nan) 
# 3. Fitar (Treinar) usando os embeddings pré-calculados
knn_grid_baai_20_under.fit(X_baai_pca_20_under, y_baai_under)
# Out:
# Fitting 20 folds for each of 38 candidates, totalling 760 fits
# GridSearchCV(cv=20, estimator=KNeighborsClassifier(), n_jobs=-1,
#              param_grid={'n_neighbors': range(2, 21),
#                          'weights': ['uniform', 'distance']},
#              scoring='accuracy', verbose=1)

# %%
print("Melhor acurácia média:", knn_grid_baai_20_under.best_score_)
print("Melhores parâmetros:", knn_grid_baai_20_under.best_params_)

best_models_list.append({
    "features": "embeddings baai-bge-3",
    "PCA": "20",
    "undersampled": True,
    "accuracy": knn_grid_baai_20_under.best_score_,
    "params": knn_grid_baai_20_under.best_params_.copy(),
})
# Out:
# Melhor acurácia média: 0.6509229976390993
# Melhores parâmetros: {'n_neighbors': 16, 'weights': 'distance'}

# %% [markdown]
# ### Liberação de Memória

# %%
del X_baai_pca_20
del knn_grid_baai_20

del X_baai_pca_20_under
del knn_grid_baai_20_under

gc.collect()
# Out:
# 54

# %% [markdown]
# ## PCA 30

# %% [markdown]
# ### Full sample

# %%
ipca_30 = IncrementalPCA(n_components=30, batch_size=batch_size)
X_baai_pca_30 = ipca_30.fit_transform(X_baai_norm)

for i, batch in enumerate(np.array_split(X_baai_norm, n_batches)):
    print(f"Fitando batch {i+1}")
    ipca_30.partial_fit(batch)
    print(f"Lote {i+1}/{n_batches} concluído")
# Out:
# Fitando batch 1
# Lote 1/5 concluído
# Fitando batch 2
# Lote 2/5 concluído
# Fitando batch 3
# Lote 3/5 concluído
# Fitando batch 4
# Lote 4/5 concluído
# Fitando batch 5
# Lote 5/5 concluído

# %%
#Fazer PCA

knn_grid_baai_30 = GridSearchCV(knn, # Modelo
                                { # Parâmetros
                                    'n_neighbors': range(2, 31),
                                    'weights': ['uniform', 'distance']
                                }, 
                                cv=10, # Configs 
                                n_jobs=-1, 
                                scoring="accuracy", 
                                verbose=1, 
                                error_score=np.nan) 


knn_grid_baai_30.fit(X_baai_pca_30, y_baai)
# Out:
# Fitting 10 folds for each of 58 candidates, totalling 580 fits
# GridSearchCV(cv=10, estimator=KNeighborsClassifier(), n_jobs=-1,
#              param_grid={'n_neighbors': range(2, 31),
#                          'weights': ['uniform', 'distance']},
#              scoring='accuracy', verbose=1)

# %%
print("Melhor acurácia média:", knn_grid_baai_30.best_score_)
print("Melhores parâmetros:", knn_grid_baai_30.best_params_)

best_models_list.append({
    "features": "embeddings baai-bge-3",
    "PCA": "30",
    "undersampled": False,
    "accuracy": knn_grid_baai_30.best_score_,
    "params": knn_grid_baai_30.best_params_.copy(),
})
# Out:
# Melhor acurácia média: 0.6595542262103976
# Melhores parâmetros: {'n_neighbors': 14, 'weights': 'distance'}

# %% [markdown]
# ### Undersample

# %%
ipca_30_under = IncrementalPCA(n_components=30, batch_size=batch_size)
X_baai_pca_30_under = ipca_30_under.fit_transform(X_baai_norm)

for i, batch in enumerate(np.array_split(X_baai_norm, n_batches)):
    print(f"Fitando batch {i+1}")
    ipca_30_under.partial_fit(batch)
    print(f"Lote {i+1}/{n_batches} concluído")
# Out:
# Fitando batch 1
# Lote 1/5 concluído
# Fitando batch 2
# Lote 2/5 concluído
# Fitando batch 3
# Lote 3/5 concluído
# Fitando batch 4
# Lote 4/5 concluído
# Fitando batch 5
# Lote 5/5 concluído

# %%
#Fazer PCA

knn_grid_baai_30_under = GridSearchCV(knn, # Modelo
                                { # Parâmetros
                                    'n_neighbors': range(2, 31),
                                    'weights': ['uniform', 'distance']
                                }, 
                                cv=10, # Configs 
                                n_jobs=-1, 
                                scoring="accuracy", 
                                verbose=1, 
                                error_score=np.nan) 
# 3. Fitar (Treinar) usando os embeddings pré-calculados
knn_grid_baai_30_under.fit(X_baai_pca_30_under, y_baai_under)
# Out:
# Fitting 10 folds for each of 58 candidates, totalling 580 fits
# GridSearchCV(cv=10, estimator=KNeighborsClassifier(), n_jobs=-1,
#              param_grid={'n_neighbors': range(2, 31),
#                          'weights': ['uniform', 'distance']},
#              scoring='accuracy', verbose=1)

# %%
print("Melhor acurácia média:", knn_grid_baai_30_under.best_score_)
print("Melhores parâmetros:", knn_grid_baai_30_under.best_params_)

best_models_list.append({
    "features": "embeddings baai-bge-3",
    "PCA": "30",
    "undersampled": True,
    "accuracy": knn_grid_baai_30_under.best_score_,
    "params": knn_grid_baai_30_under.best_params_.copy(),
})
# Out:
# Melhor acurácia média: 0.6595542262103976
# Melhores parâmetros: {'n_neighbors': 14, 'weights': 'distance'}

# %% [markdown]
# ### Liberação de memória

# %%
del X_baai_pca_30
del knn_grid_baai_30

del X_baai_pca_30_under
del knn_grid_baai_30_under

gc.collect()
# Out:
# 54

# %% [markdown]
# ## PCA 40

# %% [markdown]
# ### Full sample

# %%
ipca_40 = IncrementalPCA(n_components=40, batch_size=batch_size)
X_baai_pca_40 = ipca_40.fit_transform(X_baai_norm)

for i, batch in enumerate(np.array_split(X_baai_norm, n_batches)):
    print(f"Fitando batch {i+1}")
    ipca_40.partial_fit(batch)
    print(f"Lote {i+1}/{n_batches} concluído")
# Out:
# Fitando batch 1
# Lote 1/5 concluído
# Fitando batch 2
# Lote 2/5 concluído
# Fitando batch 3
# Lote 3/5 concluído
# Fitando batch 4
# Lote 4/5 concluído
# Fitando batch 5
# Lote 5/5 concluído

# %%
#Fazer PCA

knn_grid_baai_40 = GridSearchCV(knn, # Modelo
                                { # Parâmetros
                                    'n_neighbors': range(2, 41),
                                    'weights': ['uniform', 'distance']
                                }, 
                                cv=10, # Configs 
                                n_jobs=-1, 
                                scoring="accuracy", 
                                verbose=1, 
                                error_score=np.nan) 


knn_grid_baai_40.fit(X_baai_pca_40, y_baai)
# Out:
# Fitting 10 folds for each of 78 candidates, totalling 780 fits
# GridSearchCV(cv=10, estimator=KNeighborsClassifier(), n_jobs=-1,
#              param_grid={'n_neighbors': range(2, 41),
#                          'weights': ['uniform', 'distance']},
#              scoring='accuracy', verbose=1)

# %%
print("Melhor acurácia média:", knn_grid_baai_40.best_score_)
print("Melhores parâmetros:", knn_grid_baai_40.best_params_)

best_models_list.append({
    "features": "embeddings baai-bge-3",
    "PCA": "40",
    "undersampled": False,
    "accuracy": knn_grid_baai_40.best_score_,
    "params": knn_grid_baai_40.best_params_.copy(),
})
# Out:
# Melhor acurácia média: 0.6648884857795437
# Melhores parâmetros: {'n_neighbors': 10, 'weights': 'distance'}

# %% [markdown]
# ### Undersample

# %%
ipca_40_under = IncrementalPCA(n_components=40, batch_size=batch_size)
X_baai_pca_40_under = ipca_40_under.fit_transform(X_baai_norm)

for i, batch in enumerate(np.array_split(X_baai_norm, n_batches)):
    print(f"Fitando batch {i+1}")
    ipca_40_under.partial_fit(batch)
    print(f"Lote {i+1}/{n_batches} concluído")
# Out:
# Fitando batch 1
# Lote 1/5 concluído
# Fitando batch 2
# Lote 2/5 concluído
# Fitando batch 3
# Lote 3/5 concluído
# Fitando batch 4
# Lote 4/5 concluído
# Fitando batch 5
# Lote 5/5 concluído

# %%
#Fazer PCA

knn_grid_baai_40_under = GridSearchCV(knn, # Modelo
                                { # Parâmetros
                                    'n_neighbors': range(2, 41),
                                    'weights': ['uniform', 'distance']
                                }, 
                                cv=10, # Configs 
                                n_jobs=-1, 
                                scoring="accuracy", 
                                verbose=1, 
                                error_score=np.nan) 
# 3. Fitar (Treinar) usando os embeddings pré-calculados
knn_grid_baai_40_under.fit(X_baai_pca_40_under, y_baai_under)
# Out:
# Fitting 10 folds for each of 78 candidates, totalling 780 fits
# GridSearchCV(cv=10, estimator=KNeighborsClassifier(), n_jobs=-1,
#              param_grid={'n_neighbors': range(2, 41),
#                          'weights': ['uniform', 'distance']},
#              scoring='accuracy', verbose=1)

# %%
print("Melhor acurácia média:", knn_grid_baai_40_under.best_score_)
print("Melhores parâmetros:", knn_grid_baai_40_under.best_params_)

best_models_list.append({
    "features": "embeddings baai-bge-3",
    "PCA": "40",
    "undersampled": True,
    "accuracy": knn_grid_baai_40_under.best_score_,
    "params": knn_grid_baai_40_under.best_params_.copy(),
})
# Out:
# Melhor acurácia média: 0.6648884857795437
# Melhores parâmetros: {'n_neighbors': 10, 'weights': 'distance'}

# %% [markdown]
# ### Liberação de memória

# %%
del X_baai_pca_40
del knn_grid_baai_40

del X_baai_pca_40_under
del knn_grid_baai_40_under

gc.collect()
# Out:
# 54

# %% [markdown]
# ## PCA 50

# %% [markdown]
# ### Full sample

# %%
ipca_50 = IncrementalPCA(n_components=50, batch_size=batch_size)
X_baai_pca_50 = ipca_50.fit_transform(X_baai_norm)

for i, batch in enumerate(np.array_split(X_baai_norm, n_batches)):
    print(f"Fitando batch {i+1}")
    ipca_50.partial_fit(batch)
    print(f"Lote {i+1}/{n_batches} concluído")
# Out:
# Fitando batch 1
# Lote 1/5 concluído
# Fitando batch 2
# Lote 2/5 concluído
# Fitando batch 3
# Lote 3/5 concluído
# Fitando batch 4
# Lote 4/5 concluído
# Fitando batch 5
# Lote 5/5 concluído

# %%
#Fazer PCA

knn_grid_baai_50 = GridSearchCV(knn, # Modelo
                                { # Parâmetros
                                    'n_neighbors': range(2, 51),
                                    'weights': ['uniform', 'distance']
                                }, 
                                cv=10, # Configs 
                                n_jobs=-1, 
                                scoring="accuracy", 
                                verbose=1, 
                                error_score=np.nan) 


knn_grid_baai_50.fit(X_baai_pca_50, y_baai)
# Out:
# Fitting 10 folds for each of 98 candidates, totalling 980 fits
# GridSearchCV(cv=10, estimator=KNeighborsClassifier(), n_jobs=-1,
#              param_grid={'n_neighbors': range(2, 51),
#                          'weights': ['uniform', 'distance']},
#              scoring='accuracy', verbose=1)

# %%
print("Melhor acurácia média:", knn_grid_baai_50.best_score_)
print("Melhores parâmetros:", knn_grid_baai_50.best_params_)

best_models_list.append({
    "features": "embeddings baai-bge-3",
    "PCA": "50",
    "undersampled": False,
    "accuracy": knn_grid_baai_50.best_score_,
    "params": knn_grid_baai_50.best_params_.copy(),
})
# Out:
# Melhor acurácia média: 0.6668575809161451
# Melhores parâmetros: {'n_neighbors': 6, 'weights': 'distance'}

# %% [markdown]
# ### Undersample

# %%
ipca_50_under = IncrementalPCA(n_components=50, batch_size=batch_size)
X_baai_pca_50_under = ipca_50_under.fit_transform(X_baai_norm)

for i, batch in enumerate(np.array_split(X_baai_norm, n_batches)):
    print(f"Fitando batch {i+1}")
    ipca_50_under.partial_fit(batch)
    print(f"Lote {i+1}/{n_batches} concluído")
# Out:
# Fitando batch 1
# Lote 1/5 concluído
# Fitando batch 2
# Lote 2/5 concluído
# Fitando batch 3
# Lote 3/5 concluído
# Fitando batch 4
# Lote 4/5 concluído
# Fitando batch 5
# Lote 5/5 concluído

# %%
#Fazer PCA

knn_grid_baai_50_under = GridSearchCV(knn, # Modelo
                                { # Parâmetros
                                    'n_neighbors': range(2, 51),
                                    'weights': ['uniform', 'distance']
                                }, 
                                cv=10, # Configs 
                                n_jobs=-1, 
                                scoring="accuracy", 
                                verbose=1, 
                                error_score=np.nan) 
# 3. Fitar (Treinar) usando os embeddings pré-calculados
knn_grid_baai_50_under.fit(X_baai_pca_50_under, y_baai_under)
# Out:
# Fitting 10 folds for each of 98 candidates, totalling 980 fits
# GridSearchCV(cv=10, estimator=KNeighborsClassifier(), n_jobs=-1,
#              param_grid={'n_neighbors': range(2, 51),
#                          'weights': ['uniform', 'distance']},
#              scoring='accuracy', verbose=1)

# %%
print("Melhor acurácia média:", knn_grid_baai_50_under.best_score_)
print("Melhores parâmetros:", knn_grid_baai_50_under.best_params_)

best_models_list.append({
    "features": "embeddings baai-bge-3",
    "PCA": "50",
    "undersampled": True,
    "accuracy": knn_grid_baai_50_under.best_score_,
    "params": knn_grid_baai_50_under.best_params_.copy(),
})
# Out:
# Melhor acurácia média: 0.6668575809161451
# Melhores parâmetros: {'n_neighbors': 6, 'weights': 'distance'}

# %% [markdown]
# ### Liberação de memória

# %%
del X_baai_pca_50
del knn_grid_baai_50

del X_baai_pca_50_under
del knn_grid_baai_50_under

gc.collect()
# Out:
# 54

# %% [markdown]
# ## PCA 75

# %% [markdown]
# ### Full sample

# %%
ipca_75 = IncrementalPCA(n_components=75, batch_size=batch_size)
X_baai_pca_75 = ipca_75.fit_transform(X_baai_norm)

for i, batch in enumerate(np.array_split(X_baai_norm, n_batches)):
    print(f"Fitando batch {i+1}")
    ipca_75.partial_fit(batch)
    print(f"Lote {i+1}/{n_batches} concluído")
# Out:
# Fitando batch 1
# Lote 1/5 concluído
# Fitando batch 2
# Lote 2/5 concluído
# Fitando batch 3
# Lote 3/5 concluído
# Fitando batch 4
# Lote 4/5 concluído
# Fitando batch 5
# Lote 5/5 concluído

# %%
#Fazer PCA

knn_grid_baai_75 = GridSearchCV(knn, # Modelo
                                { # Parâmetros
                                    'n_neighbors': range(2, 76),
                                    'weights': ['uniform', 'distance']
                                }, 
                                cv=10, # Configs 
                                n_jobs=-1, 
                                scoring="accuracy", 
                                verbose=1, 
                                error_score=np.nan) 


knn_grid_baai_75.fit(X_baai_pca_75, y_baai)
# Out:
# Fitting 10 folds for each of 148 candidates, totalling 1480 fits
# GridSearchCV(cv=10, estimator=KNeighborsClassifier(), n_jobs=-1,
#              param_grid={'n_neighbors': range(2, 76),
#                          'weights': ['uniform', 'distance']},
#              scoring='accuracy', verbose=1)

# %%
print("Melhor acurácia média:", knn_grid_baai_75.best_score_)
print("Melhores parâmetros:", knn_grid_baai_75.best_params_)

best_models_list.append({
    "features": "embeddings baai-bge-3",
    "PCA": "75",
    "undersampled": False,
    "accuracy": knn_grid_baai_75.best_score_,
    "params": knn_grid_baai_75.best_params_.copy(),
})
# Out:
# Melhor acurácia média: 0.6719400404381513
# Melhores parâmetros: {'n_neighbors': 6, 'weights': 'distance'}

# %% [markdown]
# ### Undersample

# %%
ipca_75_under = IncrementalPCA(n_components=75, batch_size=batch_size)
X_baai_pca_75_under = ipca_75_under.fit_transform(X_baai_norm)

for i, batch in enumerate(np.array_split(X_baai_norm, n_batches)):
    print(f"Fitando batch {i+1}")
    ipca_75_under.partial_fit(batch)
    print(f"Lote {i+1}/{n_batches} concluído")
# Out:
# Fitando batch 1
# Lote 1/5 concluído
# Fitando batch 2
# Lote 2/5 concluído
# Fitando batch 3
# Lote 3/5 concluído
# Fitando batch 4
# Lote 4/5 concluído
# Fitando batch 5
# Lote 5/5 concluído

# %%
#Fazer PCA

knn_grid_baai_75_under = GridSearchCV(knn, # Modelo
                                { # Parâmetros
                                    'n_neighbors': range(2, 76),
                                    'weights': ['uniform', 'distance']
                                }, 
                                cv=10, # Configs 
                                n_jobs=-1, 
                                scoring="accuracy", 
                                verbose=1, 
                                error_score=np.nan) 
# 3. Fitar (Treinar) usando os embeddings pré-calculados
knn_grid_baai_75_under.fit(X_baai_pca_75_under, y_baai_under)
# Out:
# Fitting 10 folds for each of 148 candidates, totalling 1480 fits
# GridSearchCV(cv=10, estimator=KNeighborsClassifier(), n_jobs=-1,
#              param_grid={'n_neighbors': range(2, 76),
#                          'weights': ['uniform', 'distance']},
#              scoring='accuracy', verbose=1)

# %%
print("Melhor acurácia média:", knn_grid_baai_75_under.best_score_)
print("Melhores parâmetros:", knn_grid_baai_75_under.best_params_)

best_models_list.append({
    "features": "embeddings baai-bge-3",
    "PCA": "75",
    "undersampled": True,
    "accuracy": knn_grid_baai_75_under.best_score_,
    "params": knn_grid_baai_75_under.best_params_.copy(),
})
# Out:
# Melhor acurácia média: 0.6719400404381513
# Melhores parâmetros: {'n_neighbors': 6, 'weights': 'distance'}

# %% [markdown]
# ### Liberação de memória

# %%
del X_baai_pca_75
del knn_grid_baai_75

del X_baai_pca_75_under
del knn_grid_baai_75_under

gc.collect()
# Out:
# 54

# %% [markdown]
# ## PCA 100

# %% [markdown]
# ### Full sample

# %%
ipca_100 = IncrementalPCA(n_components=100, batch_size=batch_size)
X_baai_pca_100 = ipca_100.fit_transform(X_baai_norm)

for i, batch in enumerate(np.array_split(X_baai_norm, n_batches)):
    print(f"Fitando batch {i+1}")
    ipca_100.partial_fit(batch)
    print(f"Lote {i+1}/{n_batches} concluído")
# Out:
# Fitando batch 1
# Lote 1/5 concluído
# Fitando batch 2
# Lote 2/5 concluído
# Fitando batch 3
# Lote 3/5 concluído
# Fitando batch 4
# Lote 4/5 concluído
# Fitando batch 5
# Lote 5/5 concluído

# %%
#Fazer PCA

knn_grid_baai_100 = GridSearchCV(knn, # Modelo
                                { # Parâmetros
                                    'n_neighbors': range(2, 101),
                                    'weights': ['uniform', 'distance']
                                }, 
                                cv=10, # Configs 
                                n_jobs=-1, 
                                scoring="accuracy", 
                                verbose=1, 
                                error_score=np.nan) 


knn_grid_baai_100.fit(X_baai_pca_100, y_baai)
# Out:
# Fitting 10 folds for each of 198 candidates, totalling 1980 fits
# GridSearchCV(cv=10, estimator=KNeighborsClassifier(), n_jobs=-1,
#              param_grid={'n_neighbors': range(2, 101),
#                          'weights': ['uniform', 'distance']},
#              scoring='accuracy', verbose=1)

# %%
print("Melhor acurácia média:", knn_grid_baai_100.best_score_)
print("Melhores parâmetros:", knn_grid_baai_100.best_params_)

best_models_list.append({
    "features": "embeddings baai-bge-3",
    "PCA": "100",
    "undersampled": False,
    "accuracy": knn_grid_baai_100.best_score_,
    "params": knn_grid_baai_100.best_params_.copy(),
})
# Out:
# Melhor acurácia média: 0.6754432332990268
# Melhores parâmetros: {'n_neighbors': 6, 'weights': 'distance'}

# %% [markdown]
# ### Undersample

# %%
ipca_100_under = IncrementalPCA(n_components=100, batch_size=batch_size)
X_baai_pca_100_under = ipca_100_under.fit_transform(X_baai_norm)

for i, batch in enumerate(np.array_split(X_baai_norm, n_batches)):
    print(f"Fitando batch {i+1}")
    ipca_100_under.partial_fit(batch)
    print(f"Lote {i+1}/{n_batches} concluído")
# Out:
# Fitando batch 1
# Lote 1/5 concluído
# Fitando batch 2
# Lote 2/5 concluído
# Fitando batch 3
# Lote 3/5 concluído
# Fitando batch 4
# Lote 4/5 concluído
# Fitando batch 5
# Lote 5/5 concluído

# %%
#Fazer PCA

knn_grid_baai_100_under = GridSearchCV(knn, # Modelo
                                { # Parâmetros
                                    'n_neighbors': range(2, 101),
                                    'weights': ['uniform', 'distance']
                                }, 
                                cv=10, # Configs 
                                n_jobs=-1, 
                                scoring="accuracy", 
                                verbose=1, 
                                error_score=np.nan) 
# 3. Fitar (Treinar) usando os embeddings pré-calculados
knn_grid_baai_100_under.fit(X_baai_pca_100_under, y_baai_under)
# Out:
# Fitting 10 folds for each of 198 candidates, totalling 1980 fits
# GridSearchCV(cv=10, estimator=KNeighborsClassifier(), n_jobs=-1,
#              param_grid={'n_neighbors': range(2, 101),
#                          'weights': ['uniform', 'distance']},
#              scoring='accuracy', verbose=1)

# %%
print("Melhor acurácia média:", knn_grid_baai_100_under.best_score_)
print("Melhores parâmetros:", knn_grid_baai_100_under.best_params_)

best_models_list.append({
    "features": "embeddings baai-bge-3",
    "PCA": "100",
    "undersampled": True,
    "accuracy": knn_grid_baai_100_under.best_score_,
    "params": knn_grid_baai_100_under.best_params_.copy(),
})
# Out:
# Melhor acurácia média: 0.6754432332990268
# Melhores parâmetros: {'n_neighbors': 6, 'weights': 'distance'}

# %% [markdown]
# ### Liberação de memória

# %%
del X_baai_pca_100
del knn_grid_baai_100

del X_baai_pca_100_under
del knn_grid_baai_100_under

gc.collect()
# Out:
# 54

# %% [markdown]
# ## PCA 150

# %% [markdown]
# ### Full sample

# %%
ipca_150 = IncrementalPCA(n_components=150, batch_size=batch_size)
X_baai_pca_150 = ipca_150.fit_transform(X_baai_norm)

for i, batch in enumerate(np.array_split(X_baai_norm, n_batches)):
    print(f"Fitando batch {i+1}")
    ipca_150.partial_fit(batch)
    print(f"Lote {i+1}/{n_batches} concluído")
# Out:
# Fitando batch 1
# Lote 1/5 concluído
# Fitando batch 2
# Lote 2/5 concluído
# Fitando batch 3
# Lote 3/5 concluído
# Fitando batch 4
# Lote 4/5 concluído
# Fitando batch 5
# Lote 5/5 concluído

# %%
#Fazer PCA

knn_grid_baai_150 = GridSearchCV(knn, # Modelo
                                { # Parâmetros
                                    'n_neighbors': range(2, 151),
                                    'weights': ['uniform', 'distance']
                                }, 
                                cv=10, # Configs 
                                n_jobs=-1, 
                                scoring="accuracy", 
                                verbose=1, 
                                error_score=np.nan) 


knn_grid_baai_150.fit(X_baai_pca_150, y_baai)
# Out:
# Fitting 10 folds for each of 298 candidates, totalling 2980 fits
# GridSearchCV(cv=10, estimator=KNeighborsClassifier(), n_jobs=-1,
#              param_grid={'n_neighbors': range(2, 151),
#                          'weights': ['uniform', 'distance']},
#              scoring='accuracy', verbose=1)

# %%
print("Melhor acurácia média:", knn_grid_baai_150.best_score_)
print("Melhores parâmetros:", knn_grid_baai_150.best_params_)

best_models_list.append({
    "features": "embeddings baai-bge-3",
    "PCA": "150",
    "undersampled": False,
    "accuracy": knn_grid_baai_150.best_score_,
    "params": knn_grid_baai_150.best_params_.copy(),
})
# Out:
# Melhor acurácia média: 0.6802739347134813
# Melhores parâmetros: {'n_neighbors': 6, 'weights': 'distance'}

# %% [markdown]
# ### Undersample

# %%
ipca_150_under = IncrementalPCA(n_components=150, batch_size=batch_size)
X_baai_pca_150_under = ipca_150_under.fit_transform(X_baai_norm)

for i, batch in enumerate(np.array_split(X_baai_norm, n_batches)):
    print(f"Fitando batch {i+1}")
    ipca_150_under.partial_fit(batch)
    print(f"Lote {i+1}/{n_batches} concluído")
# Out:
# Fitando batch 1
# Lote 1/5 concluído
# Fitando batch 2
# Lote 2/5 concluído
# Fitando batch 3
# Lote 3/5 concluído
# Fitando batch 4
# Lote 4/5 concluído
# Fitando batch 5
# Lote 5/5 concluído

# %%
#Fazer PCA

knn_grid_baai_150_under = GridSearchCV(knn, # Modelo
                                { # Parâmetros
                                    'n_neighbors': range(2, 151),
                                    'weights': ['uniform', 'distance']
                                }, 
                                cv=10, # Configs 
                                n_jobs=-1, 
                                scoring="accuracy", 
                                verbose=1, 
                                error_score=np.nan) 
# 3. Fitar (Treinar) usando os embeddings pré-calculados
knn_grid_baai_150_under.fit(X_baai_pca_150_under, y_baai_under)
# Out:
# Fitting 10 folds for each of 298 candidates, totalling 2980 fits
# GridSearchCV(cv=10, estimator=KNeighborsClassifier(), n_jobs=-1,
#              param_grid={'n_neighbors': range(2, 151),
#                          'weights': ['uniform', 'distance']},
#              scoring='accuracy', verbose=1)

# %%
print("Melhor acurácia média:", knn_grid_baai_150_under.best_score_)
print("Melhores parâmetros:", knn_grid_baai_150_under.best_params_)

best_models_list.append({
    "features": "embeddings baai-bge-3",
    "PCA": "150",
    "undersampled": True,
    "accuracy": knn_grid_baai_150_under.best_score_,
    "params": knn_grid_baai_150_under.best_params_.copy(),
})
# Out:
# Melhor acurácia média: 0.6802739347134813
# Melhores parâmetros: {'n_neighbors': 6, 'weights': 'distance'}

# %% [markdown]
# ### Liberação de memória

# %%
del X_baai_pca_150
del knn_grid_baai_150

del X_baai_pca_150_under
del knn_grid_baai_150_under

gc.collect()
# Out:
# 27

# %% [markdown]
# ## PCA 200

# %% [markdown]
# ### Full sample

# %%
ipca_200 = IncrementalPCA(n_components=200, batch_size=batch_size)
X_baai_pca_200 = ipca_200.fit_transform(X_baai_norm)

for i, batch in enumerate(np.array_split(X_baai_norm, n_batches)):
    print(f"Fitando batch {i+1}")
    ipca_200.partial_fit(batch)
    print(f"Lote {i+1}/{n_batches} concluído")
# Out:
# Fitando batch 1
# Lote 1/5 concluído
# Fitando batch 2
# Lote 2/5 concluído
# Fitando batch 3
# Lote 3/5 concluído
# Fitando batch 4
# Lote 4/5 concluído
# Fitando batch 5
# Lote 5/5 concluído

# %%
#Fazer PCA

knn_grid_baai_200 = GridSearchCV(knn, # Modelo
                                { # Parâmetros
                                    'n_neighbors': range(2, 201),
                                    'weights': ['uniform', 'distance']
                                }, 
                                cv=10, # Configs 
                                n_jobs=-1, 
                                scoring="accuracy", 
                                verbose=1, 
                                error_score=np.nan) 


knn_grid_baai_200.fit(X_baai_pca_200, y_baai)
# Out:
# Fitting 10 folds for each of 398 candidates, totalling 3980 fits

# %%
print("Melhor acurácia média:", knn_grid_baai_200.best_score_)
print("Melhores parâmetros:", knn_grid_baai_200.best_params_)

best_models_list.append({
    "features": "embeddings baai-bge-3",
    "PCA": "200",
    "undersampled": False,
    "accuracy": knn_grid_baai_200.best_score_,
    "params": knn_grid_baai_200.best_params_.copy(),
})

# %% [markdown]
# ### Undersample

# %%
ipca_200_under = IncrementalPCA(n_components=200, batch_size=batch_size)
X_baai_pca_200_under = ipca_200_under.fit_transform(X_baai_norm)

for i, batch in enumerate(np.array_split(X_baai_norm, n_batches)):
    print(f"Fitando batch {i+1}")
    ipca_200_under.partial_fit(batch)
    print(f"Lote {i+1}/{n_batches} concluído")

# %%
#Fazer PCA

knn_grid_baai_200_under = GridSearchCV(knn, # Modelo
                                { # Parâmetros
                                    'n_neighbors': range(2, 201),
                                    'weights': ['uniform', 'distance']
                                }, 
                                cv=10, # Configs 
                                n_jobs=-1, 
                                scoring="accuracy", 
                                verbose=1, 
                                error_score=np.nan) 
# 3. Fitar (Treinar) usando os embeddings pré-calculados
knn_grid_baai_200_under.fit(X_baai_pca_200_under, y_baai_under)

# %%
print("Melhor acurácia média:", knn_grid_baai_200_under.best_score_)
print("Melhores parâmetros:", knn_grid_baai_200_under.best_params_)

best_models_list.append({
    "features": "embeddings baai-bge-3",
    "PCA": "200",
    "undersampled": True,
    "accuracy": knn_grid_baai_200_under.best_score_,
    "params": knn_grid_baai_200_under.best_params_.copy(),
})

# %% [markdown]
# ### Liberação de memória

# %%
del X_baai_pca_200
del knn_grid_baai_200

del X_baai_pca_200_under
del knn_grid_baai_200_under

gc.collect()

# %% [markdown]
# ## Seleciona melhores parâmetros

# %%
best_score = -1
best = 0
for idx, candidate in enumerate(best_models_list):
    if candidate["accuracy"] > best_score:
        best = idx
        best_score = candidate["accuracy"]

print(f"O melhor classificador encontrado pelas pipelines é -->    feature={best_models_list[best]["features"]}\n"+
                                                                   f"PCA={best_models_list[best]["PCA"]}"+
                                                                   f"undersampled={best_models_list[best]["undersampled"]}")
print(f"Melhor acucácia encontrada:  {best_models_list[best]['accuracy']}")
print(f"Melhores parametros encontrados:  {best_models_list[best]['params']}")
